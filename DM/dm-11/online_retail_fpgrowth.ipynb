# %% [markdown]
# ### Sample program for Association Analysis (Market Basket Analysis) using FP-Growth

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import pyfpgrowth  # https://fp-growth.readthedocs.io/en/latest/

# %% [markdown]
# #### Parameters

# %%
csv_in = 'online_retail_small_cleaned.csv'

# %% [markdown]
# #### Read CSV file

# %%
df = pd.read_csv(csv_in, delimiter=',', skiprows=0, header=0)
print(df.shape)
print(df.info())
display(df.head())
# Out:
# (59145, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59145 entries, 0 to 59144
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    59145 non-null  int64
#  1   StockCode    59145 non-null  object
#  2   Description  59145 non-null  object
#  3   Quantity     59145 non-null  int64
#  4   InvoiceDate  59145 non-null  object
#  5   UnitPrice    59145 non-null  float64
#  6   CustomerID   59145 non-null  int64
#  7   Country      59145 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 3.6+ MB
# None
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536386     84880                WHITE WIRE EGG HOLDER        36
# 1     536386    85099C       JUMBO  BAG BAROQUE BLACK WHITE       100
# 2     536386    85099B              JUMBO BAG RED RETROSPOT       100
# 3     536404     22297            HEART IVORY TRELLIS SMALL        24
# 4     536404     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN        12
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 09:57:00       4.95       16029  United Kingdom
# 1  2010-12-01 09:57:00       1.65       16029  United Kingdom
# 2  2010-12-01 09:57:00       1.65       16029  United Kingdom
# 3  2010-12-01 11:29:00       1.25       16218  United Kingdom
# 4  2010-12-01 11:29:00       1.25       16218  United Kingdom

# %% [markdown]
# #### Check appearance of each StockCode

# %%
top_sc = df['StockCode'].value_counts()
print(top_sc.size)
print(top_sc.head())
# Out:
# 3140
# 85123A    315
# 85099B    246
# 22423     229
# 84879     213
# 47566     208
# Name: StockCode, dtype: int64

# %% [markdown]
# #### Format transaction data
# Before:
# ```
# invoice1, stockcode1, ...
# invoice1, stockcode2, ...
# invoice2, stockcode1, ...
# invoice3, stockcode1, ...
# invoice3, stockcode3, ...
# ```
#
# After:
# ```
# [
#   [stockcode1, stockcode2],
#   [stockcode1],
#   [stockcode1, stockcode3],
#   ...
# ]
# ```
#
# and stockcode should be interger.

# %% [markdown]
# #### Assign an integer (ID) to each stockcode

# %%
id2sc = sorted(list(set(df['StockCode'])))
sc2id = {}
for i in range(len(id2sc)):
    sc2id[id2sc[i]] = i

# %%
df['StockCode_ID'] = df['StockCode'].map(lambda x: sc2id[x])
display(df.head())
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536386     84880                WHITE WIRE EGG HOLDER        36
# 1     536386    85099C       JUMBO  BAG BAROQUE BLACK WHITE       100
# 2     536386    85099B              JUMBO BAG RED RETROSPOT       100
# 3     536404     22297            HEART IVORY TRELLIS SMALL        24
# 4     536404     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN        12
#
#            InvoiceDate  UnitPrice  CustomerID         Country  StockCode_ID
# 0  2010-12-01 09:57:00       4.95       16029  United Kingdom          2775
# 1  2010-12-01 09:57:00       1.65       16029  United Kingdom          2907
# 2  2010-12-01 09:57:00       1.65       16029  United Kingdom          2906
# 3  2010-12-01 11:29:00       1.25       16218  United Kingdom          1078
# 4  2010-12-01 11:29:00       1.25       16218  United Kingdom          1517

# %% [markdown]
# #### Grouping transaction data by InvoiceNo

# %%
invoices = []
for r in df.groupby('InvoiceNo'):
    # print(len(r))  # debug
    # print(r[0])  # debug
    # print(r[1])  # debug
    #break  # debug
    s1 = set(r[1]['StockCode_ID'])
    invoices.append(list(s1))
print(len(invoices))
print(invoices)
# Out:
# 492, 1499, 1628, 1373, 229, 485, 1131, 2162, 888, 890], [1923, 1155, 137, 2830, 1807, 532, 1557, 1559, 2585, 1561, 1331, 1332, 1461, 1081, 1339, 2752, 1346, 3139, 1348, 842, 843, 1356, 1482, 846, 849, 3027, 3028, 3029, 855, 2269, 2015, 2275, 2022, 2023, 1018], [129, 1922, 1154, 1924, 2181, 1926, 2055, 135, 2185, 2186, 651, 2060, 138, 134, 1807, 2196, 2198, 1177, 922, 1697, 673, 2084, 1958, 2219, 2228, 2229, 2230, 1718, 1588, 824, 1722, 2876, 2240, 704, 1986, 1987, 2256, 2257, 2258, 1105, 213, 2264, 2265, 2266, 1886, 2271, 992, 1381, 1382, 2023, 1253, 2537, 1131, 1906, 1910, 2169], [2048, 899, 1156, 2437, 262, 2439, 2057, 2059, 399, 146, 916, 1685, 2073, 1185, 1186, 299, 1201, 946, 947, 2485, 1214, 2114, 2013, 2014, 2527, 2017, 229, 2024, 1641, 1642, 2032, 1393, 2293, 892, 2047], [1156, 1925, 137, 139, 140, 797, 1999, 2264, 2266, 2271, 992, 1121, 1122, 1124, 111, 112, 113, 114, 117, 1917], [1798, 7, 1288, 1194, 2099, 2100, 2101, 2102, 1332, 1331, 2105, 1221, 1222, 1349, 980, 981, 1116, 1250, 1511, 2792, 2796, 2554], [2181, 262, 2055, 2056, 2824, 2053, 12, 910, 1166, 895, 1307, 1308, 2076, 673, 290, 1189, 1962, 1195, 430, 943, 1840, 1591, 825, 827, 60, 705, 452, 1481, 1994, 1482, 460, 1995, 1997, 457, 2257, 1234, 2258, 1878, 1879, 2647, 1239, 1368, 1887, 96, 1375, 2913, 1891, 1892, 2915, 746, 2802, 2165, 247, 2169, 767], [1221, 2892, 2575, 2099, 532, 888, 889, 2554, 891], [289, 2181, 1415, 1642, 2186, 367, 2191, 1585, 1586, 1587, 1588, 213, 2262, 2193, 1592, 1593, 895], [1920, 2177, 129, 2947, 1157, 902, 903, 1416, 1158, 780, 783, 1813, 1431, 799, 800, 1444, 947, 1331, 1332, 1998, 340, 982, 2264, 2906, 992, 1642, 2289, 892, 1149, 2558, 2047], [1547, 929, 674, 1443, 982, 2774, 1758, 1759, 1760, 1761, 1762, 1517, 624, 625, 2034, 626, 628, 629, 627, 2553], [2183, 2184, 2185, 2826, 2186, 1416, 1021, 147, 895, 1818, 2078, 289, 553, 2346, 554, 304, 1844, 1469, 2240, 2643, 2011, 2396, 1887, 482, 2405, 2022, 2023, 872, 1641, 1642, 367, 1018, 1915, 1020, 381, 382, 1023], [2177, 517, 1805, 1806, 1807, 3095, 3097, 2468, 1317, 2212, 2856, 2857, 426, 2090, 2091, 1962, 683, 3114, 3115, 1331, 1332, 1973, 1334, 1849, 954, 1850, 955, 958, 1086, 2119, 968, 2377, 2250, 1483, 1484, 1485, 3022, 1487, 2379, 3025, 338, 724, 982, 343, 3033, 346, 3043, 2148, 3045, 3046, 3044, 108, 2802, 3067, 3069, 1535], [386, 1415, 1416, 1189, 1448, 557, 2352, 944, 1969, 2362, 1723, 2629, 2632, 1992, 328, 330, 213, 739, 1125, 1387, 2419, 383], [2048, 1537, 2564, 2566, 2058, 2065, 2067, 2068, 2070, 1048, 2094, 1075, 1078, 1086, 2129, 1632, 1125, 1132, 111, 112, 113, 114, 2162, 1150, 1151, 1153, 130, 1155, 1156, 1157, 1158, 136, 137, 139, 2190, 2191, 2193, 2194, 2195, 2196, 1177, 673, 2752, 1229, 2264, 2265, 2266, 2271, 228, 229, 234, 774, 775, 1287, 1288, 262, 1291, 1292, 1294, 1807, 1820, 2333, 2343, 1325, 1326, 832, 835, 1362, 1363, 343, 2918, 367, 368, 895, 1920, 1921, 1919, 1923, 2947, 1925, 1926, 1415, 1416, 923, 924, 2986, 2988, 2989, 2990, 3002, 1984, 1493, 469, 2014, 992, 1011], [2059, 2060, 2071, 2072, 1577, 2609, 2610, 2611, 52, 565, 566, 567, 2626, 586, 590, 591, 609, 611, 613, 1128, 1143, 1166, 1168, 1169, 1683, 1183, 1185, 1186, 1187, 1697, 1705, 1205, 182, 185, 1724, 1725, 188, 1728, 2240, 1730, 1731, 1733, 1735, 2771, 1246, 735, 1251, 234, 235, 241, 242, 753, 758, 767, 769, 262, 1799, 2825, 2826, 2827, 1315, 1316, 1317, 1318, 2861, 819, 821, 2877, 331, 334, 1361, 1369, 1889, 370, 2419, 883, 884, 391, 908, 397, 2455, 920, 922, 930, 943, 944, 442, 443, 444, 1994, 971, 1996, 2014, 1001, 1003], [2240, 2214, 2185, 2186, 2222, 2223, 2258], [2946, 2182, 903, 2184, 2185, 786, 917, 792, 2202, 1312, 1697, 553, 1321, 556, 557, 1838, 1711, 944, 1840, 1841, 1842, 178, 1712, 2230, 2224, 704, 580, 1864, 586, 1484, 1996, 1230, 1487, 590, 591, 980, 342, 1240, 1753, 1241, 1758, 1374, 1375, 2149, 1517, 1518, 1519, 1520, 2161, 752, 1649, 1651, 757, 1650, 1653, 1144, 1148, 766, 2815], [2752, 1697, 1336, 324, 1604, 855, 1998, 1331, 1332, 1748, 2774, 1335, 1887, 1338, 1884, 28 ...

# %% [markdown]
# #### Market Basket Analysis by FP-Growth

# %%
# %time patterns = pyfpgrowth.find_frequent_patterns(invoices, 40)
# Out:
# CPU times: user 181 ms, sys: 1.03 ms, total: 182 ms
# Wall time: 180 ms

# %%
#print(patterns)

# %%
# %time rules = pyfpgrowth.generate_association_rules(patterns, 0.8)
# Out:
# CPU times: user 0 ns, sys: 365 µs, total: 365 µs
# Wall time: 367 µs

# %%
print(rules)
# Out:
# {(1473,): ((1475,), 0.803921568627451), (1332,): ((1331,), 0.8243243243243243), (1474, 1478): ((1475,), 0.8035714285714286), (1475, 1478): ((1474,), 0.8490566037735849), (138, 1156): ((137,), 0.8333333333333334), (140, 1156): ((137,), 0.8448275862068966), (1154, 1156): ((137,), 0.828125)}

# %%
results = []
for x in rules:
    ret = [x, rules[x][0], rules[x][1]]
    results.append(ret)
df_res = pd.DataFrame(results)
df_res.columns = ['LHS', 'RHS', 'Conf']

# %%
display(df_res.sort_values(by='Conf', ascending=False))
# Out:
#             LHS      RHS      Conf
# 3  (1475, 1478)  (1474,)  0.849057
# 5   (140, 1156)   (137,)  0.844828
# 4   (138, 1156)   (137,)  0.833333
# 6  (1154, 1156)   (137,)  0.828125
# 1       (1332,)  (1331,)  0.824324
# 0       (1473,)  (1475,)  0.803922
# 2  (1474, 1478)  (1475,)  0.803571

# %% [markdown]
# #### Get original StockCode

# %%
print(id2sc[1474])
print(id2sc[1475])
print(id2sc[1478])
# Out:
# 22726
# 22727
# 22730

# %% [markdown]
# #### Calculation of Lift

# %%
n_all = len(invoices)
lift = []
for i in range(df_res.shape[0]):
    rhs = df_res.at[i, 'RHS']
    conf = df_res.at[i, 'Conf']
    n_rhs = 0
    for items in invoices:
        if set(items) >= set(rhs):
            n_rhs += 1
    lift1 = conf / (n_rhs / n_all)
    lift.append(lift1)
    
df_res['Lift'] = lift

# %%
display(df_res.sort_values(by='Conf', ascending=False))
# Out:
#             LHS      RHS      Conf       Lift
# 3  (1475, 1478)  (1474,)  0.849057  18.287883
# 5   (140, 1156)   (137,)  0.844828  11.883621
# 4   (138, 1156)   (137,)  0.833333  11.721939
# 6  (1154, 1156)   (137,)  0.828125  11.648677
# 1       (1332,)  (1331,)  0.824324  28.057558
# 0       (1473,)  (1475,)  0.803922  16.540386
# 2  (1474, 1478)  (1475,)  0.803571  16.533182
